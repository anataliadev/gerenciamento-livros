# %%
import matplotlib.pyplot as plt

# Classe para representar um livro
class Livro:
  def __init__(self, titulo, autor, ano_publicacao):
    self.titulo = titulo
    self.autor = autor
    self.ano_publicacao = ano_publicacao

  def __str__(self):
    return f"{self.titulo} por {self.autor}, Publicados em ({self.ano_publicacao})"

# %%
# Criar uma lista de livros
biblioteca = []

# Lista para armazenar anos de publicação
anos = []

# Função para adicionar um livro à biblioteca
def adicionar_livro(titulo, autor, ano_publicacao):
  novo_livro = Livro(titulo, autor, ano_publicacao)
  biblioteca.append(novo_livro)
  anos.append(ano_publicacao) # Adicionar o ano à lista anos
  print(f"O livro '{titulo}' foi adicionado à biblioteca")

# Função para listar todos os livros na biblioteca
def listar_livros():
    print("Livros na Biblioteca")
    for livro in biblioteca:
      print(livro)

# Adicionar alguns livros à biblioteca
adicionar_livro("Fausto", "Johann Wolfgang von Goethe", 1808)
adicionar_livro("Orgulho e Preconceito", "Jane Austen", 1813)
adicionar_livro("Frankenstein", "Mary Shelley", 1818)
adicionar_livro("O Fantasma de Canterville", "Oscar Wilde", 1887)
adicionar_livro("Apanhador no Campo de Centeio", "J.D. Salinger", 1951)
# Out:
# O livro 'Fausto' foi adicionado à biblioteca
# O livro 'Orgulho e Preconceito' foi adicionado à biblioteca
# O livro 'Frankenstein' foi adicionado à biblioteca
# O livro 'O Fantasma de Canterville' foi adicionado à biblioteca
# O livro 'Apanhador no Campo de Centeio' foi adicionado à biblioteca

# %%
# Lista todos os livros na biblioteca
listar_livros()

# Criar um gráfico de livros por anos
anos = list(set(anos)) # Remove duplicatas dos anos
anos.sort()

# Contagem de livros por ano
contagem_por_ano = [anos.count(ano) for ano in anos]

# Criar o gráfico de linha
plt.plot(anos, contagem_por_ano, marker='o', linestyle='-')
plt.xlabel('Ano de Publicação')
plt.ylabel('Número de Livros')
plt.title('Distribuição de Livros na Biblioteca por Ano de Publicação')

# Adicionar rótulos aos pontos de dados
for i, valor in enumerate(contagem_por_ano):
  plt.text(anos[i], valor, str(valor), ha='center', va='bottom')

plt.grid(True)

plt.show()
# Out:
# Livros na Biblioteca
# Fausto por Johann Wolfgang von Goethe, Publicados em (1808)
# Orgulho e Preconceito por Jane Austen, Publicados em (1813)
# Frankenstein por Mary Shelley, Publicados em (1818)
# O Fantasma de Canterville por Oscar Wilde, Publicados em (1887)
# Apanhador no Campo de Centeio por J.D. Salinger, Publicados em (1951)
